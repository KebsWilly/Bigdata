# %%
import pandas
data = pandas.read_csv("https://modcom.co.ke/data/datasets/pima.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
print(data.shape)
# Out:
# (768, 9)

# %%
print(data.describe())
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
print(data.corr())
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
# class imbalance
print(data.groupby('Outcome').size())
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
# we create synthetic data - this is machine generated data
array = dataframe.values
# Out:
# Outcome
# 0    27
# 1    36
# Name: Age, dtype: int64

# %%
print(data.groupby('Outcome')['Age'].median())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print(data.isnull().sum())

# %%
#machine Learning with python What are we predicting 'class' - Classification
#what are the features and the outome
#features sepallength sepalwidth petallength petalwidth - predictors
#outcome = class = predicted
#features/input - X
#outcome/target/output - Y
#convert your data to an array
array = data.values

# Step 1: Split your data to x-y columns
# : means all the rows 
X = array[:, 0:8]  # upto 3 columns
Y = array[:, 8] # 4th column only

#Step 2:
#Question: if we give the model X,Y we will have used all our records. How do we test it?
# we have to give th emodel 70% , 80% , 60%
#My choice : 70% training, 30 % testing

import sklearn
from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X,Y,test_size=0.30,
                                                                   random_state=42)

#Step 3:
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,Y_train) #70%
print("Model is training......")

#step 4: Evaluate/test
# remember we have the 30% not used, we ask the model to predict using the X_test, Y_test
predictions = lr.predict(X_test)

#Step 5:
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(accuracy_score(Y_test, predictions))

#More evaluations
#Last step

#Predict a new flower
newprediction = lr.predict([[4,150,70,0,80,40.5,0.234,20]])
print(newprediction)

#remove warnings
import warnings
warnings.filterwarnings('ignore', category = FutureWarning)
# Out:
# Model is training......
# 0.7575757575757576
# [1.]
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
